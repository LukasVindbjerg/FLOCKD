# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import torchvision
import torchvision.transforms as transforms
import os
from models.model import SimpleMLP

# %%
# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
# Hyperparameters
input_size = 28 * 28  # MNIST images are 28x28
hidden_size = 32
output_size = 10  # 10 classes for digits 0-9
batch_size = 64
learning_rate = 0.001
num_epochs = 5

# %%
transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Lambda(lambda x: x.view(-1))  # Flatten from (1, 28, 28) to (784,)
    ])
    
train_dataset = torchvision.datasets.FashionMNIST(root='./data', train=True, download=True, transform=transform)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# %%
save_dir = "trainedModels/fashionMNISTmodels"
os.makedirs(save_dir, exist_ok=True)

# %%
for i in range(16):
    print(f"Training model {i}...")

    # Different weight initialization with different seeds
    torch.manual_seed(i)

    model = SimpleMLP(input_size, hidden_size, output_size).to(device)
    model.train()

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    for epoch in range(num_epochs): 
        for batch_idx, (data, targets) in enumerate(train_loader):
            data, targets = data.to(device), targets.to(device)

            optimizer.zero_grad()
            outputs = model(data)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()
            if batch_idx % 100 == 0:
                print(f"Epoch [{epoch+1}/{num_epochs}], Step [{batch_idx}/{len(train_loader)}], Loss: {loss.item():.4f}")

    torch.save(model.state_dict(), f"{save_dir}/fashionMNISTmodel{i}.pth")

print("All models trained and saved")
# Out:
# Training model 0...
# Epoch [1/5], Step [0/938], Loss: 2.3400
# Epoch [1/5], Step [100/938], Loss: 0.6857
# Epoch [1/5], Step [200/938], Loss: 0.6454
# Epoch [1/5], Step [300/938], Loss: 0.6154
# Epoch [1/5], Step [400/938], Loss: 0.4540
# Epoch [1/5], Step [500/938], Loss: 0.4555
# Epoch [1/5], Step [600/938], Loss: 0.5807
# Epoch [1/5], Step [700/938], Loss: 0.4961
# Epoch [1/5], Step [800/938], Loss: 0.5027
# Epoch [1/5], Step [900/938], Loss: 0.3910
# Epoch [2/5], Step [0/938], Loss: 0.3536
# Epoch [2/5], Step [100/938], Loss: 0.5225
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 14
#      11 optimizer = optim.Adam(model.parameters(), lr=learning_rate)
#      13 for epoch in range(num_epochs):
# ---> 14     for batch_idx, (data, targets) in enumerate(train_loader):
#      15         data, targets = data.to(device), targets.to(device)
# ...
